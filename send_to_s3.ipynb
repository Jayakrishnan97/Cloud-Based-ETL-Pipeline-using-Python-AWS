# %%
import boto3

# %%
s3 = boto3.client("s3")

# %%
bucket_name = "my5956659buck"
local_file = "/home/jay/Python_DSA/python/projects/socialmedia_students/output.parquet"
s3_key = "raw/socialmedia_students/output.parquet"

# %%
s3.upload_file(local_file, bucket_name, s3_key)
